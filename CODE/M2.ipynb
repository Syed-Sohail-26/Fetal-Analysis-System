# %%
import pandas as pd 
import numpy as n
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv('A.csv')
d.head()
# Out:
#     DS   DP   DR   DL    LBE     LB   AC   FM   UC  ASTV  MSTV  ALTV  MLTV  \
# 0  0.0  0.0  0.0  0.0  120.0  120.0  0.0  0.0  0.0  73.0   0.5  43.0   2.4
# 1  0.0  0.0  0.0  2.0  132.0  132.0  4.0  0.0  4.0  17.0   2.1   0.0  10.4
# 2  0.0  0.0  0.0  2.0  133.0  133.0  2.0  0.0  5.0  16.0   2.1   0.0  13.4
# 3  0.0  0.0  0.0  2.0  134.0  134.0  2.0  0.0  6.0  16.0   2.4   0.0  23.0
# 4  0.0  0.0  0.0  0.0  132.0  132.0  4.0  0.0  5.0  16.0   2.4   0.0  19.9
#
#    NSP
# 0  2.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %%
d.columns
# Out:
# Index(['DS', 'DP', 'DR', 'DL', 'LBE', 'LB', 'AC', 'FM', 'UC', 'ASTV', 'MSTV',
#        'ALTV', 'MLTV', 'NSP'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(d['DS'],color='red')

plt.subplot(1,2,2)
plt.hist(d['DP'],color='blue')
# Out:
# (array([1949.,    0.,  109.,    0.,    0.,   49.,    0.,   19.,    0.,
#            2.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
d.hist(figsize=(15,55),layout=(15,4), color='red')
plt.show()

# %%
d['DR'].hist(figsize=(10,5),color='red')
# Out:
# <AxesSubplot:>

# %%
plt.bar(d['DL'],d['LBE'], color='red') # scatter, plot, triplot, stackplot
# Out:
# <BarContainer object of 2129 artists>

# %%
plt.boxplot(d['LB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2dd356ff5e0>,
#   <matplotlib.lines.Line2D at 0x2dd356ff8b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2dd356ffb80>,
#   <matplotlib.lines.Line2D at 0x2dd356ffe50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2dd356ff310>],
#  'medians': [<matplotlib.lines.Line2D at 0x2dd3570f160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2dd3570f430>],
#  'means': []}

# %%
d['AC'].plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(d['FM'], color='red') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.residplot(d['UC'],d['ASTV'], color='red') # residplot, scatterplot
# Out:
# C:\Users\SPIRO15\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='UC', ylabel='ASTV'>

# %%
def plot(d, variable):
    dataframe_pie = d[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/d.shape[0]*100,2)

plot(d, 'NSP')
# Out:
# 1.0    77.74
# 2.0    13.86
# 3.0     8.27
# Name: NSP, dtype: float64
