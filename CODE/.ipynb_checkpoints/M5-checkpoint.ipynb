# %% [markdown]
# # SUPPORT VECTOR CLASSIFIER

# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('A.csv')
df.head()
# Out:
#     DS   DP   DR   DL    LBE     LB   AC   FM   UC  ASTV  MSTV  ALTV  MLTV  \
# 0  0.0  0.0  0.0  0.0  120.0  120.0  0.0  0.0  0.0  73.0   0.5  43.0   2.4
# 1  0.0  0.0  0.0  2.0  132.0  132.0  4.0  0.0  4.0  17.0   2.1   0.0  10.4
# 2  0.0  0.0  0.0  2.0  133.0  133.0  2.0  0.0  5.0  16.0   2.1   0.0  13.4
# 3  0.0  0.0  0.0  2.0  134.0  134.0  2.0  0.0  6.0  16.0   2.4   0.0  23.0
# 4  0.0  0.0  0.0  0.0  132.0  132.0  4.0  0.0  5.0  16.0   2.4   0.0  19.9
#
#    NSP
# 0  2.0
# 1  1.0
# 2  1.0
# 3  1.0
# 4  1.0

# %%
df = df.drop_duplicates()
sum(df.duplicated())
# Out:
# 0

# %%
df=df.dropna()
df
# Out:
#        DS   DP   DR   DL    LBE     LB   AC   FM   UC  ASTV  MSTV  ALTV  MLTV  \
# 0     0.0  0.0  0.0  0.0  120.0  120.0  0.0  0.0  0.0  73.0   0.5  43.0   2.4
# 1     0.0  0.0  0.0  2.0  132.0  132.0  4.0  0.0  4.0  17.0   2.1   0.0  10.4
# 2     0.0  0.0  0.0  2.0  133.0  133.0  2.0  0.0  5.0  16.0   2.1   0.0  13.4
# 3     0.0  0.0  0.0  2.0  134.0  134.0  2.0  0.0  6.0  16.0   2.4   0.0  23.0
# 4     0.0  0.0  0.0  0.0  132.0  132.0  4.0  0.0  5.0  16.0   2.4   0.0  19.9
# ...   ...  ...  ...  ...    ...    ...  ...  ...  ...   ...   ...   ...   ...
# 2121  0.0  0.0  0.0  0.0  140.0  140.0  0.0  0.0  6.0  79.0   0.2  25.0   7.2
# 2122  0.0  0.0  0.0  0.0  140.0  140.0  1.0  0.0  9.0  78.0   0.4  22.0   7.1
# 2123  0.0  0.0  0.0  0.0  140.0  140.0  1.0  0.0  7.0  79.0   0.4  20.0   6.1
# 2124  0.0  0.0  0.0  0.0  140.0  140.0  1.0  0.0  9.0  78.0   0.4  27.0   7.0
# 2125  0.0  0.0  0.0  0.0  142.0  142.0  1.0  1.0  5.0  74.0   0.4  36.0   5.0
#
#       NSP
# 0     2.0
# ...

# %%
df.columns
# Out:
# Index(['DS', 'DP', 'DR', 'DL', 'LBE', 'LB', 'AC', 'FM', 'UC', 'ASTV', 'MSTV',
#        'ALTV', 'MLTV', 'NSP'],
#       dtype='object')

# %%
x = df.drop(labels='NSP', axis=1)
y = df.loc[:,'NSP']

# %%
import imblearn
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

ros =RandomOverSampler(random_state=42)
x,y=ros.fit_resample(x,y)
print("OUR DATASET COUNT         : ", Counter(y))
print("OVER SAMPLING DATA COUNT  : ", Counter(y))
# Out:
# OUR DATASET COUNT         :  Counter({2.0: 1646, 1.0: 1646, 3.0: 1646})
# OVER SAMPLING DATA COUNT  :  Counter({2.0: 1646, 1.0: 1646, 3.0: 1646})

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=1, stratify=y)
print("Number of training dataset : ", len(x_train))
print("Number of test dataset     : ", len(x_test))
print("Total number of dataset    : ", len(x_train)+len(x_test))
# Out:
# Number of training dataset :  3950
# Number of test dataset     :  988
# Total number of dataset    :  4938

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC

# %%
SVM = SVC()
SVM.fit(x_train,y_train)
predicted = SVM.predict(x_test)

# %%
cr = classification_report(y_test,predicted)
print('Classification report of SUPPORT VECTOR CLASSIFIER Result is:\n',cr)
print("\n")
# Out:
# Classification report of SUPPORT VECTOR CLASSIFIER Result is:
#                precision    recall  f1-score   support
#
#          1.0       0.81      0.75      0.78       329
#          2.0       0.79      0.83      0.81       330
#          3.0       0.80      0.81      0.81       329
#
#     accuracy                           0.80       988
#    macro avg       0.80      0.80      0.80       988
# weighted avg       0.80      0.80      0.80       988

# %%
cm = confusion_matrix(y_test,predicted)
print('Confusion Matrix result of SUPPORT VECTOR CLASSIFIER is:',cm)
print("\n")
# Out:
# Confusion Matrix result of SUPPORT VECTOR CLASSIFIER is: [[247  35  47]
#  [ 36 274  20]
#  [ 21  40 268]]

# %%
accuracy = cross_val_score(SVM, x, y, scoring='accuracy')
print('Cross validation test results of accuracy:', accuracy)
print("\n")
# Out:
# Cross validation test results of accuracy: [0.82793522 0.81680162 0.88157895 0.81458967 0.64842958]

# %%
a = accuracy.mean() * 100
print("Accuracy Result of SUPPORT VECTOR CLASSIFIER is:",a)
# Out:
# Accuracy Result of SUPPORT VECTOR CLASSIFIER is: 79.78670079453953

# %%
def plot_confusion_matrix(cm, title='Confusion matrix-SUPPORT VECTOR CLASSIFIER', cmap=plt.cm.cool):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

cm1=confusion_matrix(y_test, predicted)
print('Confusion matrix-SUPPORT VECTOR CLASSIFIER:')
print(cm)
plot_confusion_matrix(cm)
# Out:
# Confusion matrix-SUPPORT VECTOR CLASSIFIER:
# [[247  35  47]
#  [ 36 274  20]
#  [ 21  40 268]]

# %%
import matplotlib.pyplot as plt
df2 = pd.DataFrame()
df2["y_test"] = y_test
df2["predicted"] = predicted
df2.reset_index(inplace=True)
plt.figure(figsize=(20, 5))
plt.plot(df2["predicted"][:100], marker='x', linestyle='dashed', color='red')
plt.plot(df2["y_test"][:100],  marker='o', linestyle='dashed', color='green')
plt.show()
